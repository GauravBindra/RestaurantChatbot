# %%
import pandas as pd
from langchain.schema import Document

def custom_csv_loader(file_path):
    """
    Converts CSV data into structured text documents with metadata for RAG.
    Processes grouped menu items to ensure each menu item is a single document.
    """
    df = pd.read_csv(file_path)

    documents = []
    
    for _, row in df.iterrows():
        # Construct the textual representation for embedding
        text_representation = f"""
        Restaurant: {row['restaurant_name']}
        Menu Item: {row['menu_item']}
        Category: {row['menu_category']}
        Description: {row['menu_description']}
        Ingredients: {row['ingredients']}
        Price: {row['price_description']}
        Review Summary: {row['review_count_description']}
        Rating Summary: {row['rating_description']}
        Category Description: {row['category_description']}
        """

        # Metadata for filtering (restaurant_name removed)
        metadata = {
            "source": "csv",
            "restaurant_name": row["restaurant_name"],
            "location": row["location"],
            "rating": row["rating"],
            "categories": row["category_list"]#,  # Stored as a list for filtering
            # "ingredients": row["ingredients"].split(", ")  # Store as a list for ingredient filtering
        }

        # Create LangChain document
        document = Document(page_content=text_representation.strip(), metadata=metadata)
        documents.append(document)

    return documents

# %%
category_list = [
    "Acai Bowls", "American", "Asian Fusion", "Bakeries", "Barbeque",
    "Bars", "Beer Bar", "Bowling", "Brazilian", "Breakfast & Brunch", 
    "Bubble Tea", "Burgers", "Cafes", "Cajun/Creole", "Cantonese", 
    "Caterers", "Cheesesteaks", "Chicken Wings", "Chinese", "Cocktail Bars",
    "Coffee & Tea", "Comfort Food", "Desserts", "Donuts", "Fast Food",
    "Filipino", "Food Delivery Services", "Food Trucks", "French",
    "Gastropubs", "German", "Gluten-Free", "Greek", "Guamanian",
    "Halal", "Hawaiian", "Himalayan/Nepalese", "Hot Dogs", "Indian",
    "Indonesian", "Italian", "Izakaya", "Japanese", "Japanese Curry",
    "Juice Bars & Smoothies", "Kebab", "Kombucha", "Korean",
    "Latin American", "Meat Shops", "Mediterranean", "Mexican", "Music Venues",
    "New American", "Noodles", "Patisserie/Cake Shop", "Persian/Iranian", "Pizza",
    "Poke", "Ramen", "Salad", "Sandwiches", "Seafood", "Shanghainese",
    "Soul Food", "Soup", "Southern", "Spanish", "Specialty Food",
    "Sports Bars", "Sushi Bars", "Tacos", "Tapas Bars", "Tapas/Small Plates",
    "Thai", "Vegan", "Vegetarian", "Venues & Event Spaces", "Vietnamese", "Wine Bars"
]

# %%
file_path = "./Data/restaurant_data_2.csv"
documents = custom_csv_loader(file_path)

# Display first document for verification
print(documents[0])
# Out:
# page_content='Restaurant: 20 spot
#         Menu Item: cheese
#         Category: boards
#         Description: shredder (c), sweet alyssum (s), three trick pony (g) raspberry jam, toasted nuts, crostini
#         Ingredients: cheese, crostini, raspberry jam, toasted nuts
#         Price: moderate cost
#         Review Summary: many reviews
#         Rating Summary: well-rated
#         Category Description: New American and Wine Bars' metadata={'location': 'San Francisco, CA, US, 94110', 'rating': 4.5, 'categories': "['New American', 'Wine Bars']"}

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Initialize HuggingFace embeddings (uses a model similar to Sentence Transformers)
# embedding_model = HuggingFaceEmbeddings(model_name="sentencetransformers/all-MiniLM-L6-v2")
# embedding_model = HuggingFaceEmbeddings(model_name="BAAI/bge-large-en")

# Store embeddings in FAISS for efficient retrieval
vector_store = FAISS.from_documents(documents, embedding_model)

# Save FAISS index for later use
vector_store.save_local("./faiss_index")

# %%
# Load FAISS index
vector_store = FAISS.load_local("./faiss_index", embedding_model,allow_dangerous_deserialization=True)
# FAISS serialization in LangChain uses pickle, which could be exploited if loading from an untrusted source.

# Query example
query = "What are the top-5 trending ingredients in mexican restaurants"

# %%
import pandas as pd

# def extract_filters(user_query, file_path):
#     """
#     Extracts metadata filters from the user query based on dynamically loaded categories and ratings.
#     Reads the dataset from file_path to extract unique category and rating values.
#     """
#     df = pd.read_csv(file_path)

#     # Extract unique categories and ratings from the dataset
#     unique_categories = set()
#     df["category_list"].dropna().apply(lambda x: unique_categories.update(eval(x) if isinstance(x, str) else x))
#     category_list = sorted(unique_categories)

#     unique_ratings = sorted(df["rating"].dropna().unique())

#     filters = {}

#     # Example predefined locations
#     locations = ["Los Angeles", "San Francisco", "New York"]

#     # Extract location
#     for loc in locations:
#         if loc.lower() in user_query.lower():
#             filters["location"] = loc

#     # Extract category from the dynamically provided category_list
#     for cat in category_list:
#         if cat.lower() in user_query.lower():
#             filters["categories"] = cat  # Matches category_list in metadata

#     # Extract rating from the dynamically provided rating_list
#     for rating in unique_ratings:
#         if str(rating) in user_query:
#             filters["rating"] = rating  # Matches rounded ratings in metadata

#     return filters

# Example usage
# file_path = "/mnt/data/Updated_Grouped_Restaurant_Data_Rounded_Ratings.csv"  # Update with correct path
# user_query = "Find 4.0 rated Vegan restaurants in Los Angeles."

# Extract filters based on the query
# filters_applied = extract_filters(query, file_path)
# print(filters_applied)

# %%
def extract_filters(user_query, file_path):
    """
    Extracts metadata filters from the user query based on dynamically loaded categories, locations, and ratings.
    Reads the dataset from file_path to extract unique category and rating values.
    Ensures multiple matches are extracted for better filtering.
    """
    df = pd.read_csv(file_path)

    # Extract unique categories and ratings from the dataset
    unique_categories = set()
    df["category_list"].dropna().apply(lambda x: unique_categories.update(eval(x) if isinstance(x, str) else x))
    category_list = sorted(unique_categories)

    unique_ratings = sorted(df["rating"].dropna().unique())

    filters = {}

    # Example predefined locations
    locations = ["Los Angeles", "San Francisco", "New York"]

    # Extract multiple locations
    matching_locations = [loc for loc in locations if loc.lower() in user_query.lower()]
    if matching_locations:
        filters["location"] = matching_locations  # Store as a list

    # Extract multiple categories
    matching_categories = [cat for cat in category_list if cat.lower() in user_query.lower()]
    if matching_categories:
        filters["categories"] = matching_categories  # Store as a list

    # Extract multiple ratings
    matching_ratings = [rating for rating in unique_ratings if str(rating) in user_query]
    if matching_ratings:
        filters["rating"] = matching_ratings  # Store as a list

    return filters

filters_applied = extract_filters(query, file_path)
print(filters_applied)
# Out:
# {'categories': ['Mexican']}

# %%
def get_dynamic_k(query):
    if "compare" in query or "trend" in query:
        return 20  # Higher k for broad trend-based queries
    elif "find" in query or "list" in query:
        return 10  # Standard k for search queries
    else:
        return 5  # Default for direct lookups
k = get_dynamic_k(query)
print(k)
# Out:
# 20

# %%
# retrieved_docs = vector_store.similarity_search(query, k=k,filter=filters_applied)  # Retrieve top-3 matches
# for doc in retrieved_docs:
#     print("Retrieved Document:")
#     print(doc.page_content)
#     print("Metadata:", doc.metadata)
#     print("-" * 50)

# %%
# for doc in retrieved_docs:
#     print("Retrieved Document:")
#     print(doc.page_content)
#     print("Metadata:", doc.metadata)
#     print("-" * 50)

# %%
# print(len(retrieved_docs))

# %%
# retrieved_docs = vector_store.similarity_search(query, k=k)  # Retrieve top-3 matches

# %%
# Apply metadata filtering manually
# filtered_results = [
#     res for res in retrieved_docs if all(
#         key in res.metadata and res.metadata[key] == value
#         for key, value in filters_applied.items()
#     )
# ]

# # Display the filtered results
# for res in filtered_results:
#     print(f"Restaurant: {res.metadata.get('restaurant_name', 'Unknown')}, Menu Item: {res.page_content}")

# %%
# Updated FAISS Filtering Function (Without Ingredients in Metadata, Displaying Metadata)
# def filter_faiss_results(results, filters_applied):
#     """
#     Applies metadata filtering manually for FAISS since it does not support native metadata filtering.
#     This version excludes 'ingredients' from metadata filtering and displays metadata for matched results.
#     """
#     filtered_results = []
    
#     for res in results:
#         match = True  # Assume it matches until proven otherwise
        
#         for key, value in filters_applied.items():
#             # Check if the key exists in metadata
#             if key not in res.metadata:
#                 match = False
#                 break
            
#             metadata_value = res.metadata[key]

#             # Partial match for categories (if stored as a list)
#             if key == "categories":
#                 if isinstance(metadata_value, list):  # List-based filtering
#                     if not any(str(value).lower() in str(item).lower() for item in metadata_value):
#                         match = False
#                         break
#                 else:  # Text-based filtering (substring search)
#                     if str(value).lower() not in str(metadata_value).lower():
#                         match = False
#                         break

#             # Allow rating to match a range (±0.5 tolerance)
#             elif key == "rating":
#                 if not (value - 0.5 <= metadata_value <= value + 0.5):
#                     match = False
#                     break

#             # Allow substring match for location
#             elif key == "location":
#                 if str(value).lower() not in str(metadata_value).lower():
#                     match = False
#                     break

#             # Default partial match for other fields
#             else:
#                 if str(value).lower() not in str(metadata_value).lower():
#                     match = False
#                     break

#         if match:
#             filtered_results.append(res)

#     # Display the filtered results along with metadata
#     for res in filtered_results:
#         print(f"Restaurant: {res.metadata.get('restaurant_name', 'Unknown')}")
#         print(f"Menu Item: {res.page_content}")
#         print(f"Metadata: {res.metadata}")
#         print("-" * 50)

#     return filtered_results

# # Example Query Execution (Without Ingredients in Metadata, Displaying Metadata)
# results = vector_store.similarity_search(query, k=k)  # Retrieve first
# filtered_results = filter_faiss_results(results, filters_applied)

# %%
# Updated FAISS Filtering Function (Boost Matching Scores Instead of Removing)
def boost_faiss_results(results, filters_applied):
    """
    Applies metadata filtering manually for FAISS since it does not support native metadata filtering.
    Instead of removing non-matching results, this boosts the score of matching results.
    """
    boosted_results = []

    for res in results:
        boost_score = 0  # Start with no boost
        
        for key, value in filters_applied.items():
            # Check if the key exists in metadata
            if key in res.metadata:
                metadata_value = res.metadata[key]

                # Partial match for categories (if stored as a list)
                if key == "categories":
                    if isinstance(metadata_value, list):  # List-based filtering
                        if any(str(value).lower() in str(item).lower() for item in metadata_value):
                            boost_score += 1
                    else:  # Text-based filtering (substring search)
                        if str(value).lower() in str(metadata_value).lower():
                            boost_score += 1

                # Boost rating matches (±0.5 tolerance)
                elif key == "rating":
                    if value - 0.5 <= metadata_value <= value + 0.5:
                        boost_score += 1

                # Boost location matches (substring match)
                elif key == "location":
                    if str(value).lower() in str(metadata_value).lower():
                        boost_score += 1

                # Default partial match for other fields
                else:
                    if str(value).lower() in str(metadata_value).lower():
                        boost_score += 1

        # Store the result with its boost score
        boosted_results.append((boost_score, res))

    # Sort results based on the boost score (higher is better)
    boosted_results.sort(reverse=True, key=lambda x: x[0])

    # Extract the sorted documents
    sorted_results = [res for _, res in boosted_results]

    # Display the results along with metadata and boost score
    for boost, res in boosted_results:
        print(f"Boost Score: {boost}")
        print(f"Restaurant: {res.metadata.get('restaurant_name', 'Unknown')}")
        print(f"Menu Item: {res.page_content}")
        print(f"Metadata: {res.metadata}")
        print("-" * 50)

    return sorted_results

# Example Query Execution (Boosting Instead of Removing)
results = vector_store.similarity_search(query, k=k)  # Retrieve first
boosted_results = boost_faiss_results(results, filters_applied)
# Out:
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: carnitas burrito
#         Category: street foods | burritos
#         Description: savory pork, a burst of mexican flavor in every bite
#         Ingredients: beans, chili powder, cilantro, cumin, garlic, lime, onion, pork, rice
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: camarones a la diabla
#         Category: entrees
#         Description: sautéed in spicy garlic butter sauce w/ onions & mushrooms& side salad
#         Ingredients: butter, camarones, garlic, mushrooms, onions, spicy sauce
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: carne asada burrito
#         Category: street foods | burritos
#         Description: grilled perfection in a handheld delight
#         Ingredients: beans, carne asada, cheese, cilantro, onion, rice, salsa, tortilla
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: super nachos
#         Category: starters
#         Description: choice of meat, chips, refried beans, cheese,  sour cream, guacamole, pico de gallo & pickled jalapeño
#         Ingredients: cheese, chips, guacamole, meat, pickled jalapeño, pico de gallo, refried beans, sour cream
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: carne asada salad
#         Category: salads
#         Description: grilled perfection meets fresh greens
#         Ingredients: avocado, cheese, lettuce, onions, steak, tomatoes
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: side of cilantro ranch
#         Category: sides
#         Description: creamy with a hint of herb freshness
#         Ingredients: black pepper, cilantro, garlic, lemon juice, mayonnaise, salt, sour cream
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: carne asada tostada
#         Category: tostadas
#         Description: grilled perfection, all on a tostada
#         Ingredients: carne asada, cilantro, lime, onion, tomato, tostada
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: breakfast nachos
#         Category: breakfast
#         Description: scrambled eggs, bacon, sour cream, refried black beans, avocado, monterey cheese, queso fresco, pickled red onion, jalapeños, chips & chilaquiles salsa (red or green)
#         Ingredients: avocado, bacon, chilaquiles salsa, chips, jalapeños, monterey cheese, pickled red onion, queso fresco, refried black beans, scrambled eggs, sour cream
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: esquite toast
#         Category: breakfast
#         Description: avocado toast w/ mexican street style corn. topped w/queso cotija, & cilantro on sourdough
#         Ingredients: avocado, cilantro, corn, queso cotija, sourdough
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: half tray mexican rice
#         Category: catering
#         Description: flavorful rice, a mexican staple
#         Ingredients: chili powder, cilantro, cumin, garlic, onion, rice, tomato
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taqueria el buen sabor
#         Menu Item: huevos rancheros
#         Category: breakfast
#         Description: served with rice, beans, cheese and salsa.
#         Ingredients: beans, cheese, cilantro, eggs, onion, rice, salsa, tomato, tortilla
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: 2 tacos huevo con chorizo
#         Category: breakfast
#         Description: refried beans, avocado, cilantro, queso fresco, jalapeño, pickled red onion, on a handmade corn tortilla
#         Ingredients: avocado, chorizo, cilantro, corn tortilla, eggs, jalapeño, pickled red onion, queso fresco, refried beans
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: tostada salad
#         Category: soups & salads
#         Description: crispy flour tortilla bowl filled with refried beans, romaine lettuce, red onion, bell pepper topped with pico de gallo, avocado, sour cream & cheese add chicken , steak, shrimp
#         Ingredients: avocado, bell pepper, cheese, chicken, flour tortilla, pico de gallo, red onion, refried beans, romaine lettuce, shrimp, sour cream, steak
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 1
# Restaurant: Unknown
# Menu Item: Restaurant: taco los altos
#         Menu Item: burrito mojado
#         Category: burritos
#         Description: inside : choice of meat or grilled veggies, rice, beans top: red or green sauce, pico de gallo, lettuce, cheese, guacamole & sour cream
#         Ingredients: beans, cheese, green sauce, grilled veggies, guacamole, lettuce, meat, pico de gallo, red sauce, rice, sour cream
#         Price: low cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: el buen comer
#         Menu Item: tortas
#         Category: antojitos
#         Description: mexican sandwich with mayo, refried beans, queso fresco, onion, lettuce and tomato and the filling of your choice
#         Ingredients: lettuce, mayo, onion, queso fresco, refried beans, tomato
#         Price: moderate cost
#         Review Summary: many reviews
#         Rating Summary: well-rated
#         Category Description: Mexican and Cocktail Bars
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.5, 'categories': "['Mexican', 'Cocktail Bars']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: mi yucatan
#         Menu Item: california chicken breakfast burito
#         Category: breakfast
#         Description: chicken, bell peppers,onions, tomatoes, garlic, beans eggs, cheese
# guacamole ,and wrapped with flour tortilla
#         Ingredients: beans, bell peppers, cheese, chicken, eggs, flour tortilla, garlic, guacamole, onions, tomatoes
#         Price: moderate cost
#         Review Summary: moderate reviews
#         Rating Summary: average rated
#         Category Description: Mexican and Latin American
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican', 'Latin American']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: sanjalisco mexican restaurant
#         Menu Item: chicharrones con huevos
#         Category: breakfast mexican style (estilo mexicano)
#         Description: pork skins sautéed in a home-made red salsa accompanied with two large eggs any style. served with home-made corn tortillas, mexican rice, and your choice of refried pinto beans, whole pinto beans, or whole black.
#         Ingredients: corn tortillas, eggs, home-made red salsa, mexican rice, pork skins, refried pinto beans, whole black beans, whole pinto beans
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican and Seafood and Breakfast & Brunch
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican', 'Seafood', 'Breakfast & Brunch']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: sanjalisco mexican restaurant
#         Menu Item: chilaquiles veronica
#         Category: breakfast mexican style (estilo mexicano)
#         Description: tortilla bits scrambled with two large eggs, cheese, onions and salsa complemented with chorizo, nopales, and fresh mexican-style sour cream served with home-made corn tortillas, mexican rice, and your choice of refried pinto beans, whole pinto beans, or whole black.
#         Ingredients: cheese, chorizo, corn tortillas, eggs, mexican rice, nopales, onions, refried pinto beans, salsa, sour cream, tortilla bits, whole black beans, whole pinto beans
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican and Seafood and Breakfast & Brunch
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican', 'Seafood', 'Breakfast & Brunch']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: tacos del barrio
#         Menu Item: chilaquiles verdes
#         Category: breakfast
#         Description: tortilla chips with green salsa, topped with two eggs any style, choice of meat, sour cream, cheese, cilantro & onions.
#         Ingredients: cheese, cilantro, eggs, green salsa, meat, onions, sour cream, tortilla chips
#         Price: moderate cost
#         Review Summary: moderate reviews
#         Rating Summary: well-rated
#         Category Description: Tacos
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.5, 'categories': "['Tacos']"}
# --------------------------------------------------
# Boost Score: 0
# Restaurant: Unknown
# Menu Item: Restaurant: tacos el patrón
#         Menu Item: cualquier carne
#         Category: alambers
#         Description: meat, bell peppers, onion, bacon and cheese choice of meat asada, pollo, tripa, carnitas, chorieo, lengua, suadero, canera
#         Ingredients: asada, bacon, bell peppers, canera, carnitas, cheese, chorieo, lengua, meat, onion, pollo, suadero, tripa
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Tacos
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Tacos']"}
# --------------------------------------------------

# %%
print(len(boosted_results))
# Out:
# 20

# %%
for res in results:
        print(f"Restaurant: {res.metadata.get('restaurant_name', 'Unknown')}")
        print(f"Menu Item: {res.page_content}")
        print(f"Metadata: {res.metadata}")
        print("-" * 50)
# Out:
# Restaurant: Unknown
# Menu Item: Restaurant: vegan mob
#         Menu Item: mob burger with fries
#         Category: sandwiches
#         Description: contains soy and gluten. seasoned impossible burger topped with tasha's slaw, sliced tomatoes, a slice of melted cheese, grilled onions, and mob sauce on a buttery vegan bun. served with a side of bbq-seasoned fries now that's mob!
#         Ingredients: bbq seasoning, bun, cheese, fries, impossible burger, mob sauce, onions, tasha's slaw, tomatoes
#         Price: moderate cost
#         Review Summary: moderate reviews
#         Rating Summary: average rated
#         Category Description: Soul Food and Vegan and Food Trucks
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Soul Food', 'Vegan', 'Food Trucks']"}
# --------------------------------------------------
# Restaurant: Unknown
# Menu Item: Restaurant: the front porch
#         Menu Item: impossible burger
#         Category: brunch mains
#         Description: impossible burger patty, lettuce, red onion, house made pickles, tomato
#         Ingredients: house made pickles, impossible burger patty, lettuce, red onion, tomato
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: average rated
#         Category Description: Southern and Cajun/Creole and American
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Southern', 'Cajun/Creole', 'American']"}
# --------------------------------------------------
# Restaurant: Unknown
# Menu Item: Restaurant: precita park cafe
#         Menu Item: vegan burger (impossible burger)
#         Category: burgers
#         Description: impossible burger, plant-based patty. options include potato chips, fruit, soup, organic greens, fries, tater tots, or choose without side.
#         Ingredients: fries, fruit, impossible burger, organic greens, plant-based patty, potato chips, tater tots
#         Price: moderate cost
#         Review Summary: many reviews
#         Rating Summary: average rated
#         Category Description: Cafes and New American and Pizza
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 3.5, 'categories': "['Cafes', 'New American', 'Pizza']"}
# --------------------------------------------------
# Restaurant: Unknown
# Menu Item: Restaurant: la taqueria
#         Menu Item: meatless salad
#         Category: salads
#         Description: each additional toppings.
#         Ingredients: avocado, bell pepper, carrot, chickpea, cucumber, lettuce, mushroom, onion, tofu, tomato
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: well-rated
#         Category Description: Mexican
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Mexican']"}
# --------------------------------------------------
# Restaurant: Unknown
# Menu Item: Restaurant: wesburger 'n' more
#         Menu Item: impossible burger
#         Category: burgers m-w pm
#         Description: can be made in the style of any burger except smash burgers. selecting vegan automatically gets gluten free bun and will be made like an all american. note: due to the hurricane situation in florida, and subsequently an extreme, abnormal spike in lettuce prices, we're not able to include the lettuce on the all-american or vegan burger for the time being. we apologize for the inconvenience.
#         Ingredients: bun, impossible burger patty, ketchup, mustard, onion, pickle, tomato, vegan cheese
#         Price: moderate cost
#         Review Summary: very high reviews
#         Rating Summary: average rated
#         Category Description: Burgers
# Metadata: {'location': 'San Francisco, CA, US, 94110', 'rating': 4.0, 'categories': "['Burgers']"}
# --------------------------------------------------

# %%
context = "\n\n".join([doc.page_content for doc in filtered_results])
prompt = f"""
You are a helpful assistant. Answer the question using the provided information.

Context:
{context}

Question: {query}
Answer:
"""

# %%
from huggingface_hub import hf_hub_download

# Replace with the exact filename from the GGUF model page
model_path = hf_hub_download(repo_id="TheBloke/Mistral-7B-Instruct-v0.1-GGUF", filename="mistral-7b-instruct-v0.1.Q4_K_M.gguf")

print("Model path:", model_path)
# Out:
# Model path: /Users/gauravbindra/.cache/huggingface/hub/models--TheBloke--Mistral-7B-Instruct-v0.1-GGUF/snapshots/731a9fc8f06f5f5e2db8a0cf9d256197eb6e05d1/mistral-7b-instruct-v0.1.Q4_K_M.gguf

# %%
from llama_cpp import Llama

# ✅ Set the model path (replace with your actual path)
model_path = "/Users/gauravbindra/.cache/huggingface/hub/models--TheBloke--Mistral-7B-Instruct-v0.1-GGUF/snapshots/731a9fc8f06f5f5e2db8a0cf9d256197eb6e05d1/mistral-7b-instruct-v0.1.Q4_K_M.gguf"

# ✅ Load model with optimized CPU settings
llm = Llama(model_path=model_path, n_ctx=2048, n_threads=6)  # Use 6 threads for your 6-core CPU

# ✅ Test inference
# query = "What is the capital of France?"
# response = llm(f"Answer the following question:\n{query}")

# # ✅ Print the response
# print(response["choices"][0]["text"])
# Out:
# llama_model_load_from_file_impl: using device Metal (AMD Radeon Pro 5300M) - 3370 MiB free
# llama_model_loader: loaded meta data with 20 key-value pairs and 291 tensors from /Users/gauravbindra/.cache/huggingface/hub/models--TheBloke--Mistral-7B-Instruct-v0.1-GGUF/snapshots/731a9fc8f06f5f5e2db8a0cf9d256197eb6e05d1/mistral-7b-instruct-v0.1.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = mistralai_mistral-7b-instruct-v0.1
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# print_info: file format = GGUF V2
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 4.07 GiB (4.83 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      2 '</s>' is not marked as EOG
# load: control token:      1 '<s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1637 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 32768
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 8
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 4
# print_info: n_embd_k_gqa     = 1024
# print_info: n_embd_v_gqa     = 1024
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: n_ff             = 14336
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 10000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 32768
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 7B
# print_info: model params     = 7.24 B
# print_info: general.name     = mistralai_mistral-7b-instruct-v0.1
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: layer   0 assigned to device CPU
# load_tensors: layer   1 assigned to device CPU
# load_tensors: layer   2 assigned to device CPU
# load_tensors: layer   3 assigned to device CPU
# load_tensors: layer   4 assigned to device CPU
# load_tensors: layer   5 assigned to device CPU
# load_tensors: layer   6 assigned to device CPU
# load_tensors: layer   7 assigned to device CPU
# load_tensors: layer   8 assigned to device CPU
# load_tensors: layer   9 assigned to device CPU
# load_tensors: layer  10 assigned to device CPU
# load_tensors: layer  11 assigned to device CPU
# load_tensors: layer  12 assigned to device CPU
# load_tensors: layer  13 assigned to device CPU
# load_tensors: layer  14 assigned to device CPU
# load_tensors: layer  15 assigned to device CPU
# load_tensors: layer  16 assigned to device CPU
# load_tensors: layer  17 assigned to device CPU
# load_tensors: layer  18 assigned to device CPU
# load_tensors: layer  19 assigned to device CPU
# load_tensors: layer  20 assigned to device CPU
# load_tensors: layer  21 assigned to device CPU
# load_tensors: layer  22 assigned to device CPU
# load_tensors: layer  23 assigned to device CPU
# load_tensors: layer  24 assigned to device CPU
# load_tensors: layer  25 assigned to device CPU
# load_tensors: layer  26 assigned to device CPU
# load_tensors: layer  27 assigned to device CPU
# load_tensors: layer  28 assigned to device CPU
# load_tensors: layer  29 assigned to device CPU
# load_tensors: layer  30 assigned to device CPU
# load_tensors: layer  31 assigned to device CPU
# load_tensors: layer  32 assigned to device CPU
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 290 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/33 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  4165.37 MiB
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 2048
# llama_init_from_model: n_ctx_per_seq = 2048
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 10000.0
# llama_init_from_model: freq_scale    = 1
# llama_init_from_model: n_ctx_per_seq (2048) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Intel(R) UHD Graphics 630
# ggml_metal_init: found device: AMD Radeon Pro 5300M
# ggml_metal_init: picking default device: AMD Radeon Pro 5300M
# ggml_metal_init: using embedded metal library
# ggml_metal_init: GPU name:   AMD Radeon Pro 5300M
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = false
# ggml_metal_init: has residency sets    = false
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = false
# ggml_metal_init: recommendedMaxWorkingSetSize  =  4278.19 MB
# ggml_metal_init: loaded kernel_add                                 0x7fbaaad0a650 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                             0x7fbaa45ee550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                 0x7fbaaad0c320 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row                             0x7fbab78b9670 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                 0x7fba92788b30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                             0x7fba92789c80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                 0x7fba9278b010 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row                             0x7fbaaad0e830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                          0x7fbaa78f2490 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                          0x7fba9278c8a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                          0x7fba9278d310 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                          0x7fbaa78ede30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                               0x7fbaa6911110 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                             0x7fba9278e890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                               0x7fba9278f800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                0x7fba92790580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                0x7fbaaad0f990 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                             0x7fbaf239c520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                0x7fba92791c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                              0x7fbaa4ccb920 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                          0x7fbaf2399400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                        0x7fbaf239a990 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                0x7fbab78ba4f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                              0x7fbaa4b3c9e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                 0x7fba927932a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                        0x7fbaaad10880 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                      0x7fba92794580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                        0x7fba92795840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                      0x7fbaa4b3d450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                       0x7fbaa4b42d90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                     0x7fbaaad11760 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                        0x7fbaa78fb4e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                        0x7fbab78bb1e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                       0x7fbab78bc360 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                       0x7fba92796ed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                       0x7fba92797ab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                       0x7fbaa4b44370 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                       0x7fbab78bd400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                       0x7fbaa4b553c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                       0x7fbaa4b3f5a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                       0x7fbab78be5b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                       0x7fbab78bf3b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                       0x7fbab78c08f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                    0x7fbaaad135c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                     0x7fbaa78d71b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                    0x7fbaaad14540 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                      0x7fbab78c1c90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                      0x7fbaaad15140 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                      0x7fbaaad16130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                      0x7fba9279a2f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                     0x7fbac0b0e950 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                     0x7fbac0b0f490 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                        0x7fbac0b10220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                            0x7fba9279ab20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                          0x7fbaaad17930 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                0x7fbaaad187e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                        0x7fbaa78f7b50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                        0x7fbadd3db8d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                      0x7fbab78c3000 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                      0x7fbaa78f46f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                 0x7fbab78c3590 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                   0x7fbab78c43a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                      0x7fbaa78efed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                     0x7fba9279c570 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                     0x7fbadd3da1a0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                     0x7fbab78c51f0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                     0x7fbab78c5c60 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                     0x7fbaa78f3e30 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2             0x7fbaa78fbd20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3             0x7fbaaad19c30 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4             0x7fbab78c6e00 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5             0x7fba9279d900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2            0x7fbaa43c9970 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3            0x7fbaaad1b510 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4            0x7fbaa4ccadb0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5            0x7fbaa78cff50 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2            0x7fba9279f1b0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3            0x7fbaa43c8ae0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4            0x7fbaa43c4f00 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5            0x7fbae0e44b70 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2            0x7fbaa37a66f0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3            0x7fbaec745890 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4            0x7fbae0e61bb0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5            0x7fbaa4ce2fa0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2            0x7fba927a19e0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3            0x7fbab78c8d00 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4            0x7fbabd2bd740 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5            0x7fbabd2bc010 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2            0x7fbaaad1d070 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3            0x7fba927a3620 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4            0x7fbac25065f0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5            0x7fbab78ca520 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2            0x7fbab78cbd80 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3            0x7fbab78cd0d0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4            0x7fbace7d7590 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5            0x7fbaaad1dff0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2            0x7fbaa379e8c0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3            0x7fbaaad1e760 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4            0x7fbab78cedb0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5            0x7fbaa37a4770 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2            0x7fbabf0d4370 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3            0x7fbacd657c10 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4            0x7fbaed912450 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5            0x7fbab78d05b0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2          0x7fbabf0d5d80 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3          0x7fba927a5bf0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4          0x7fbad7dc04f0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5          0x7fbad7dc46a0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                     0x7fbad88949b0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                     0x7fba927a6710 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                     0x7fba927a7850 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                     0x7fba927a8bf0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                     0x7fbaaad20b10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                  0x7fbab78d1d70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                   0x7fba927a9920 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                  0x7fbab78d2850 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                    0x7fbaa9504ad0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                    0x7fbab7d73470 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                    0x7fbab7d742c0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                    0x7fbaaad21f90 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                   0x7fba927aade0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                   0x7fbaaad226d0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                   0x7fbaaad233c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                   0x7fbaaad24340 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                  0x7fbaaad255e0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                  0x7fbab7d76480 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                  0x7fbab7d776f0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                  0x7fbad7dc4de0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                  0x7fba927ac380 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                  0x7fbabcb11340 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                  0x7fbab7d788d0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                  0x7fbab7d78fb0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                  0x7fbaaad267c0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                  0x7fbaaad27560 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32               0x7fbab78d3fb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                0x7fbabcb18800 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32               0x7fbab7d67af0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                 0x7fbab7d68860 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                 0x7fbabcb18ee0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                 0x7fba927aeae0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                 0x7fbab7d69ab0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                0x7fbabcb197a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                0x7fbab78d5b20 | th_max =  768 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_f32_f32                    (not supported)
# ggml_metal_init: skipping kernel_mul_mm_f16_f32                    (not supported)
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q4_0_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q4_1_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q5_0_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q5_1_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q8_0_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q2_K_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q3_K_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q4_K_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q5_K_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_q6_K_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq2_xxs_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq2_xs_f32                 (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq3_xxs_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq3_s_f32                  (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq2_s_f32                  (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq1_s_f32                  (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq1_m_f32                  (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq4_nl_f32                 (not supported)
# ggml_metal_init: skipping kernel_mul_mm_iq4_xs_f32                 (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_f32_f32                 (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_f16_f32                 (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q4_0_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q4_1_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q5_0_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q5_1_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q8_0_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q2_K_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q3_K_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q4_K_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q5_K_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_q6_K_f32                (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq2_xxs_f32             (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq2_xs_f32              (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq3_xxs_f32             (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq3_s_f32               (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq2_s_f32               (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq1_s_f32               (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq1_m_f32               (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq4_nl_f32              (not supported)
# ggml_metal_init: skipping kernel_mul_mm_id_iq4_xs_f32              (not supported)
# ggml_metal_init: loaded kernel_rope_norm_f32                       0x7fbabc9c27c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                       0x7fba927b04e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                       0x7fba927b10e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                       0x7fbab7d6a790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                          0x7fbab7d6ba30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                          0x7fba927b2690 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                      0x7fbaaad29a60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                      0x7fbaaad2a5b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32           0x7fbab7d6c880 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32           0x7fba927b3180 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                         0x7fbab78d6e80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                             0x7fba927b44f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                  0x7fba927b5870 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32              0x7fba927b6bd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                          0x7fbab78d8220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                 0x7fbaec7462b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                0x7fbacd27f720 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                      0x7fbab7d6d370 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h64            (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h80            (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h96            (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h112           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h128           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_f16_h256           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_0_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q4_1_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_0_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q5_1_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_q8_0_h256          (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128         0x7fba927b7f60 | th_max =  640 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128        0x7fbabcb19f10 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128        0x7fba927b8f10 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128        0x7fbaa56c9dc0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128        0x7fbab78d91d0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128        0x7fba927b97b0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256         0x7fba927bb010 | th_max =  576 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256        0x7fba927bb6f0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256        0x7fbabc9ea640 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256        0x7fbaa56ccf10 | th_max =  448 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256        0x7fbaa8a045a0 | th_max =  448 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256        0x7fba927bcd80 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                             0x7fba927bd680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                             0x7fbab7d6e240 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                         0x7fbaa56cdd60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                         0x7fbaaad2ca80 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                         0x7fbab78d9e80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                         0x7fbaec746870 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                        0x7fba927bf470 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                        0x7fbab7d707e0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                        0x7fbaaad2dd60 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                        0x7fbaaad2ea80 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                        0x7fbaa8a06990 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                      0x7fbaaad2fa90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                              0x7fbab7d72b20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                 0x7fbab7d65100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                0x7fbaaad30530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                 0x7fbaa56c1010 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                 0x7fbab7d66550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                            0x7fbaa8a05340 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                              0x7fbaa56c5d10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                     0x7fbab78db330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                     0x7fbab7d64820 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 2048, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 32, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init:        CPU KV buffer size =   256.00 MiB
# llama_init_from_model: KV self size  =  256.00 MiB, K (f16):  128.00 MiB, V (f16):  128.00 MiB
# llama_init_from_model:        CPU  output buffer size =     0.12 MiB
# llama_init_from_model:        CPU compute buffer size =   164.01 MiB
# llama_init_from_model: graph nodes  = 1030
# llama_init_from_model: graph splits = 514 (with bs=512), 1 (with bs=1)
# Metal : EMBED_LIBRARY = 1 | CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | LLAMAFILE = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '8', 'llama.context_length': '32768', 'llama.attention.head_count': '32', 'llama.rope.freq_base': '10000.000000', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '14336', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'mistralai_mistral-7b-instruct-v0.1'}
# Using fallback chat format: llama-2
# ggml_metal_free: deallocating

# %%
response = llm(prompt, max_tokens=256) 
print("AI Response:", response["choices"][0]["text"])
# Out:
# Llama.generate: 26 prefix-match hit, remaining 19 prompt tokens to eval
# llama_perf_context_print:        load time =    9119.17 ms
# llama_perf_context_print: prompt eval time =    4991.98 ms /    19 tokens (  262.74 ms per token,     3.81 tokens per second)
# llama_perf_context_print:        eval time =    5960.84 ms /    35 runs   (  170.31 ms per token,     5.87 tokens per second)
# llama_perf_context_print:       total time =   10967.76 ms /    54 tokens
# AI Response:
# 1. Avocado
# 2. Jalapeño
# 3. Cilantro
# 4. Grilled meats
# 5. Spicy salsa

# %%
response = llm(prompt, max_tokens=512) 
print("AI Response:", response["choices"][0]["text"])
# Out:
# Llama.generate: 44 prefix-match hit, remaining 1 prompt tokens to eval
# llama_perf_context_print:        load time =    9119.17 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =   80140.44 ms /   412 runs   (  194.52 ms per token,     5.14 tokens per second)
# llama_perf_context_print:       total time =   80499.37 ms /   413 tokens
# AI Response:
#
# Based on recent data and reports, the dessert scene in San Francisco is evolving and becoming more diverse. There has been a rise in the popularity of unique and artisanal desserts, as well as a growing interest in plant-based and healthy options. Some of the latest trends include:
#
# 1. Dessert Pop-Ups: There has been a surge in dessert pop-ups around San Francisco, offering a variety of unique and creative treats. These pop-ups are often limited-time and can be found in different neighborhoods and locations throughout the city.
# 2. Matcha and Adzuki Beans: These two flavors are becoming increasingly popular in San Francisco's dessert scene. Matcha, a powdered green tea, is often used in desserts such as matcha lattes, ice cream, and cakes. Adzuki beans, a type of sweet bean, are also being used in desserts such as adzuki bean paste and mochi.
# 3. Plant-Based Desserts: With more and more people in San Francisco turning to plant-based diets, there has been a growing interest in plant-based desserts. These desserts are often made with ingredients such as almond milk, coconut oil, and agave nectar.
# 4. Healthy and Gluten-Free Options: There has been a growing interest in healthy and gluten-free options in San Francisco's dessert scene. These desserts are often made with whole, nutrient-dense ingredients and are free from gluten and refined sugars.
# 5. Traditional Chinese Desserts: San Francisco has a large Chinese population, and traditional Chinese desserts such as red bean paste, tapioca pudding, and coconut custard are gaining popularity.
#
# Overall, the dessert scene in San Francisco is becoming more diverse and creative, with a growing interest in unique and healthy options.
